# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasree22179/Carbon_emission_AICTE/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#elements even or odd in array
